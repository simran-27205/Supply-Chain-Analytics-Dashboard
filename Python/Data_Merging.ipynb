# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
inventory_df=pd.read_csv("/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Cleaned/Inventory_Cleaned.csv")

# %%
sales_df=pd.read_csv("/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Cleaned/Sales_Cleaned.csv")

# %%
inventory_df.head()
# Out:
#   order-now  product id                                product name  \
# 0     green          19     Nike Men's Fingertrap Max Training Shoe
# 1    orange          24                 Elevation Training Mask 2.0
# 2     green          35     adidas Brazuca 2014 Official Match Ball
# 3     green          37       adidas Kids' F5 Messi FG Soccer Cleat
# 4    orange          44  adidas Men's F10 Messi TRX FG Soccer Cleat
#
#    avg lead time  avg order qty  current stock  max lead time  max order qty  \
# 0             10              1             69             30              1
# 1             10              3            175             30              5
# 2             10              1             65             30              1
# 3             10              3            328             30              5
# 4             10              3            175             30              5
#
#    mod  reorder point  safety stock
# 0    1             35            25
# ...

# %%
sales_df.head()
# Out:
#    product_id                          product_name    category_name  \
# 0         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 1         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 2         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 3         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 4         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
#
#   department_name  order_id       order_date     shipping_date  \
# 0            Golf     53963  2/26/2017 17:17  03-02-2017 17:17
# 1            Golf      3908   2/27/2015 0:47  03-03-2015 00:47
# 2            Golf     52009   1/29/2017 4:43  02-03-2017 04:43
# 3            Golf      1179   1/18/2015 4:42    1/23/2015 4:42
# 4            Golf     56019  3/28/2017 17:36  04-02-2017 17:36
#
#   delivery_status shipping_mode     order_region  ... market order_quantity  \
# 0            Late  Second Class  Central America  ...  LATAM              2
# ...

# %%
inventory_df.columns
# Out:
# Index(['order-now', 'product id', 'product name', 'avg lead time',
#        'avg order qty', 'current stock', 'max lead time', 'max order qty',
#        'mod', 'reorder point', 'safety stock'],
#       dtype='object')

# %%
sales_df.columns
# Out:
# Index(['product_id', 'product_name', 'category_name', 'department_name',
#        'order_id', 'order_date', 'shipping_date', 'delivery_status',
#        'shipping_mode', 'order_region', 'order_country', 'market',
#        'order_quantity', 'product_price', 'sales', 'benefit_per_order',
#        'order_profit', 'scheduled_shipping_days', 'actual_shipping_days',
#        'order_status', 'customer_segment'],
#       dtype='object')

# %%
inventory_df["product id"].dtype
# Out:
# dtype('int64')

# %%
sales_df["product_id"].dtype
# Out:
# dtype('int64')

# %%
inventory_df["product id"].isin(sales_df["product_id"]).sum()
# Out:
# np.int64(118)

# %%
sales_df["product_id"].isin(inventory_df["product id"]).sum()
# Out:
# np.int64(180519)

# %%
final_df = pd.merge(
    sales_df,
    inventory_df,
    on="product_id",
    how="left"
)

# %%
inventory_df.rename(columns={"product id": "product_id"}, inplace=True)

# %%
final_df.shape
# Out:
# (180519, 31)

# %%
final_df.info
# Out:
# <bound method DataFrame.info of         product_id                          product_name     category_name  \
# 0              502  Nike Men's Dri-FIT Victory Golf Polo   Women's Apparel
# 1              502  Nike Men's Dri-FIT Victory Golf Polo   Women's Apparel
# 2              502  Nike Men's Dri-FIT Victory Golf Polo   Women's Apparel
# 3              502  Nike Men's Dri-FIT Victory Golf Polo   Women's Apparel
# 4              502  Nike Men's Dri-FIT Victory Golf Polo   Women's Apparel
# ...            ...                                   ...               ...
# 180514         365      Perfect Fitness Perfect Rip Deck            Cleats
# 180515         365      Perfect Fitness Perfect Rip Deck            Cleats
# 180516         191     Nike Men's Free 5.0+ Running Shoe  Cardio Equipment
# 180517         365      Perfect Fitness Perfect Rip Deck            Cleats
# 180518         365      Perfect Fitness Perfect Rip Deck            Cleats
#
# ...

# %%
final_df.head(1)
# Out:
#    product_id                          product_name    category_name  \
# 0         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
#
#   department_name  order_id       order_date     shipping_date  \
# 0            Golf     53963  2/26/2017 17:17  03-02-2017 17:17
#
#   delivery_status shipping_mode     order_region  ... order-now  \
# 0            Late  Second Class  Central America  ...    orange
#
#                            product name  avg lead time  avg order qty  \
# 0  Nike Men's Dri-FIT Victory Golf Polo             10              3
#
#    current stock  max lead time  max order qty  mod  reorder point  \
# 0            175             30              5    0            175
#
#   safety stock
# 0          146
#
# [1 rows x 31 columns]

# %%
final_df.isnull().sum()
# Out:
# product_id                 0
# product_name               0
# category_name              0
# department_name            0
# order_id                   0
# order_date                 0
# shipping_date              0
# delivery_status            0
# shipping_mode              0
# order_region               0
# order_country              0
# market                     0
# order_quantity             0
# product_price              0
# sales                      0
# benefit_per_order          0
# order_profit               0
# scheduled_shipping_days    0
# actual_shipping_days       0
# order_status               0
# customer_segment           0
# order-now                  0
# product name               0
# avg lead time              0
# avg order qty              0
# current stock              0
# max lead time              0
# max order qty              0
# mod                        0
# reorder point              0
# safety stock               0
# dtype: int64

# %%
final_df.to_csv(
    "/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Processed/Final_Inventory_Model.csv",
    index=False
)

# %%
final_
