# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sales_df = pd.read_csv(
    "/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Raw/Sales_Shipment_Data.csv"
)

# %%
sales_df.head()
# Out:
#    Product Category Id    Category Name                           Class  \
# 0                   24  Women's Apparel  Moderate Value-Moderate Number
# 1                   24  Women's Apparel  Moderate Value-Moderate Number
# 2                   24  Women's Apparel  Moderate Value-Moderate Number
# 3                   24  Women's Apparel  Moderate Value-Moderate Number
# 4                   24  Women's Apparel  Moderate Value-Moderate Number
#
#      Customer City Customer Country Customer Fname  Customer Id  \
# 0          Roswell          EE. UU.           Jean         5673
# 1      Los Angeles          EE. UU.           Rose         9723
# 2           Harvey          EE. UU.         Joshua         9511
# 3         Elmhurst          EE. UU.           Mary         3326
# 4  North Las Vegas          EE. UU.       Samantha          907
#
#   Customer Lname Customer Segment Customer State  ...  \
# 0           Dunn        Corporate             NM  ...
# ...

# %%
sales_df.shape
# Out:
# (180519, 46)

# %%
sales_df.columns
# Out:
# Index(['Product Category Id', 'Category Name', 'Class', 'Customer City',
#        'Customer Country', 'Customer Fname', 'Customer Id', 'Customer Lname',
#        'Customer Segment', 'Customer State', 'Customer Street',
#        'Customer Zipcode', 'Delivery Status', 'Department Id',
#        'Department Name', 'Market', 'Order City', 'Order Country',
#        'order date (DateOrders)', 'Order Id', 'Order Region', 'Order State',
#        'Order Status', 'Product Id', 'Product Name',
#        'shipping date (DateOrders)', 'Shipping Mode', 'Type',
#        'Benefit per order', 'Days for shipment (scheduled)',
#        'Days for shipping (real)', 'Latitude', 'Longitude',
#        'Order Customer Id', 'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Order Item Total',
#        'Order Profit Per Order', 'Product Price', 'Sales',
# ...

# %%
sales_df.columns = sales_df.columns.str.strip()

# %%
sales_df.columns
# Out:
# Index(['Product Category Id', 'Category Name', 'Class', 'Customer City',
#        'Customer Country', 'Customer Fname', 'Customer Id', 'Customer Lname',
#        'Customer Segment', 'Customer State', 'Customer Street',
#        'Customer Zipcode', 'Delivery Status', 'Department Id',
#        'Department Name', 'Market', 'Order City', 'Order Country',
#        'order date (DateOrders)', 'Order Id', 'Order Region', 'Order State',
#        'Order Status', 'Product Id', 'Product Name',
#        'shipping date (DateOrders)', 'Shipping Mode', 'Type',
#        'Benefit per order', 'Days for shipment (scheduled)',
#        'Days for shipping (real)', 'Latitude', 'Longitude',
#        'Order Customer Id', 'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Order Item Total',
#        'Order Profit Per Order', 'Product Price', 'Sales',
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Product Category Id            180519 non-null  int64
#  1   Category Name                  180519 non-null  object
#  2   Class                          180519 non-null  object
#  3   Customer City                  180519 non-null  object
#  4   Customer Country               180519 non-null  object
#  5   Customer Fname                 180519 non-null  object
#  6   Customer Id                    180519 non-null  int64
#  7   Customer Lname                 180511 non-null  object
#  8   Customer Segment               180519 non-null  object
#  9   Customer State                 180519 non-null  object
#  10  Customer Street                180519 non-null  object
#  11  Customer Zipcode               180516 non-null  float64
# ...

# %%
sales_df.isnull().sum()
# Out:
# Product Category Id              0
# Category Name                    0
# Class                            0
# Customer City                    0
# Customer Country                 0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 3
# Delivery Status                  0
# Department Id                    0
# Department Name                  0
# Market                           0
# Order City                       0
# Order Country                    0
# order date (DateOrders)          0
# Order Id                         0
# Order Region                     0
# Order State                      0
# Order Status                     0
# Product Id                       0
# Product Name                     0
# shipping date (DateOrders)       0
# Shipping Mode                    0
# ...

# %%
sales_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
required_columns = [
    "Product Id",
    "Product Name",
    "Category Name",
    "Department Name",
    "Order Id",
    "order date (DateOrders)",
    "shipping date (DateOrders)",
    "Delivery Status",
    "Shipping Mode",
    "Order Region",
    "Order Country",
    "Market",
    "Order Item Quantity",
    "Product Price",
    "Sales",
    "Benefit per order",
    "Order Profit Per Order",
    "Days for shipment (scheduled)",
    "Days for shipping (real)",
    "Order Status",
    "Customer Segment"
]

# %%
sales_cleaned = sales_df[required_columns]

# %%
sales_cleaned.head()
# Out:
#    Product Id                          Product Name    Category Name  \
# 0         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 1         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 2         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 3         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
# 4         502  Nike Men's Dri-FIT Victory Golf Polo  Women's Apparel
#
#   Department Name  Order Id order date (DateOrders)  \
# 0            Golf     53963         2/26/2017 17:17
# 1            Golf      3908          2/27/2015 0:47
# 2            Golf     52009          1/29/2017 4:43
# 3            Golf      1179          1/18/2015 4:42
# 4            Golf     56019         3/28/2017 17:36
#
#   shipping date (DateOrders) Delivery Status Shipping Mode     Order Region  \
# 0           03-02-2017 17:17            Late  Second Class  Central America
# 1           03-03-2015 00:47            Late  Second Class  Central America
# ...

# %%
sales_cleaned.shape
# Out:
# (180519, 21)

# %%
sales_cleaned.columns = [
    "product_id",
    "product_name",
    "category_name",
    "department_name",
    "order_id",
    "order_date",
    "shipping_date",
    "delivery_status",
    "shipping_mode",
    "order_region",
    "order_country",
    "market",
    "order_quantity",
    "product_price",
    "sales",
    "benefit_per_order",
    "order_profit",
    "scheduled_shipping_days",
    "actual_shipping_days",
    "order_status",
    "customer_segment"
]

# %%
sales_cleaned.columns
# Out:
# Index(['product_id', 'product_name', 'category_name', 'department_name',
#        'order_id', 'order_date', 'shipping_date', 'delivery_status',
#        'shipping_mode', 'order_region', 'order_country', 'market',
#        'order_quantity', 'product_price', 'sales', 'benefit_per_order',
#        'order_profit', 'scheduled_shipping_days', 'actual_shipping_days',
#        'order_status', 'customer_segment'],
#       dtype='object')

# %%
sales_cleaned.to_csv(
    "/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Cleaned/Sales_Cleaned.csv",
    index=False
)
