# %% [markdown]
# **Importing libraries and loading the dataset and checking the record present in dataset by using head function**

# %%
import pandas as pd
inventory_df=pd.read_csv("/content/Inventory_Stock_Data.csv")
inventory_df.head(10)
# Out:
#   order-now  product id                                   product name  \
# 0     green          19        Nike Men's Fingertrap Max Training Shoe
# 1    orange          24                    Elevation Training Mask 2.0
# 2     green          35        adidas Brazuca 2014 Official Match Ball
# 3     green          37          adidas Kids' F5 Messi FG Soccer Cleat
# 4    orange          44     adidas Men's F10 Messi TRX FG Soccer Cleat
# 5    orange          58  Diamondback Boys' Insight 24 Performance Hybr
# 6    orange          60                            SOLE E25 Elliptical
# 7     green          61  Diamondback Girls' Clarity 24 Hybrid Bike 201
# 8    orange          78  Nike Kids' Grade School KD VI Basketball Shoe
# 9     green          93             Under Armour Men's Tech II T-Shirt
#
#    avg lead time  avg order qty  current stock  max lead time  max order qty  \
# 0             10              1             69             30              1
# ...

# %% [markdown]
# **Checking the rows and columns present in the dataset**

# %%
inventory_df.shape
# Out:
# (118, 11)

# %%
inventory_df.describe()
# Out:
#         product id  avg lead time  avg order qty  current stock  \
# count   118.000000          118.0     118.000000     118.000000
# mean    689.576271           10.0       2.084746     160.720339
# std     403.120380            0.0       1.000652     115.003819
# min      19.000000           10.0       1.000000      35.000000
# 25%     303.500000           10.0       1.000000      63.000000
# 50%     729.000000           10.0       3.000000     175.000000
# 75%     905.750000           10.0       3.000000     321.000000
# max    1363.000000           10.0       3.000000     330.000000
#
#        max lead time  max order qty         mod  reorder point  safety stock
# count          118.0     118.000000  118.000000     118.000000    118.000000
# mean            30.0       3.169492    0.542373     110.932203     90.330508
# std              0.0       2.001303    0.500326      70.045617     60.270055
# min             30.0       1.000000    0.000000      35.000000     25.000000
# ...

# %% [markdown]
# **Checking dataset information This shows:
#
# Data types
# Missing values
# Total rows**

# %%
inventory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order-now      118 non-null    object
#  1   product id     118 non-null    int64
#  2   product name   118 non-null    object
#  3   avg lead time  118 non-null    int64
#  4   avg order qty  118 non-null    int64
#  5   current stock  118 non-null    int64
#  6   max lead time  118 non-null    int64
#  7   max order qty  118 non-null    int64
#  8   mod            118 non-null    int64
#  9   reorder point  118 non-null    int64
#  10  safety stock   118 non-null    int64
# dtypes: int64(9), object(2)
# memory usage: 10.3+ KB

# %% [markdown]
# **Checking column names present in dataset**

# %%
inventory_df.columns
# Out:
# Index(['order-now', 'product id', 'product name', 'avg lead time',
#        'avg order qty', 'current stock', 'max lead time', 'max order qty',
#        'mod', 'reorder point', 'safety stock'],
#       dtype='object')

# %% [markdown]
# **Removing Extra Spaces from columns names if present**

# %%
inventory_df.columns=inventory_df.columns.str.strip()

# %% [markdown]
# **Checking if missing values are present in dataset or not**

# %%
inventory_df.isnull().sum()
# Out:
# order-now        0
# product id       0
# product name     0
# avg lead time    0
# avg order qty    0
# current stock    0
# max lead time    0
# max order qty    0
# mod              0
# reorder point    0
# safety stock     0
# dtype: int64

# %% [markdown]
# **Checking for duplicates values present in dataset**

# %%
inventory_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Checking duplicate products ids in dataset**

# %%
inventory_df["product id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
inventory_df.columns
inventory_df.columns = [
    "order_now",
    "product_id",
    "product_name",
    "avg_lead_time",
    "avg_order_qty",
    "current_stock",
    "max_lead_time",
    "max_order_qty",
    "mod",
    "reorder_point",
    "safety_stock"
]

# %%
inventory_df.describe()
# Out:
#         product_id  avg_lead_time  avg_order_qty  current_stock  \
# count   118.000000          118.0     118.000000     118.000000
# mean    689.576271           10.0       2.084746     160.720339
# std     403.120380            0.0       1.000652     115.003819
# min      19.000000           10.0       1.000000      35.000000
# 25%     303.500000           10.0       1.000000      63.000000
# 50%     729.000000           10.0       3.000000     175.000000
# 75%     905.750000           10.0       3.000000     321.000000
# max    1363.000000           10.0       3.000000     330.000000
#
#        max_lead_time  max_order_qty         mod  reorder_point  safety_stock
# count          118.0     118.000000  118.000000     118.000000    118.000000
# mean            30.0       3.169492    0.542373     110.932203     90.330508
# std              0.0       2.001303    0.500326      70.045617     60.270055
# min             30.0       1.000000    0.000000      35.000000     25.000000
# ...

# %%
inventory_df.to_csv("Inventory_Cleaned.csv", index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'AdmitCard-220320031703 (1).pdf',
#  'IMG-20221016-WA0008.jpg',
#  'Adobe Scan Oct 17, 2022_1.pdf',
#  '20221019_190946.jpg',
#  '20221019_191020.jpg',
#  '20221019_191208.jpg',
#  '16661880190932484392156975096424.jpg',
#  '16661884233958632130302657038588.jpg',
#  '16661886128407602160809779581349.jpg',
#  '20221019_194548.jpg',
#  '16661893553916666004947933337767.jpg',
#  '16661894265832469446121460086117.jpg',
#  '16661934519727032188299563068566.jpg',
#  '20240315_182742.jpg',
#  'IMG-20240419-WA0003.jpg',
#  'RESUME.docx',
#  'SIMRANCHOUDHARY-India_Internship-certificate.pdf',
#  'SIMRANCHOUDHARY-India_Internship-certificate (1) (1).pdf',
#  'SIMRANCHOUDHARY-India_Internship-certificate (1) (5).pdf',
#  'Problem Statement .pdf',
#  'Untitled form.gform',
#  'IMG-20241125-WA0005.jpg',
#  'Dataset',
#  'Untitled spreadsheet (3).gsheet',
#  'GoogleDataAnalyticsProfessionalCertificate_Badge20250301-28-u553w5 (1).pdf',
#  'Resume.gdoc',
# ...

# %%
inventory_df = pd.read_csv(
    "/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Raw/Inventory_Stock_Data.csv"
)

# %%
inventory_df.to_csv(
    "/content/drive/MyDrive/Supply_Chain_Optimization_Project/Dataset/Cleaned/Inventory_Cleaned.csv",
    index=False
)
